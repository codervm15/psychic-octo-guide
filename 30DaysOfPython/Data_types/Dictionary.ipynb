# %%
#Dictionary is unordered, mutable, paired datatype.

#empty dictionary

d1 = {}
d2 = dict()

# %%
person={
    'first_name':'Vikrant',
    'last_name':'Mehla',
    'age':29,
    'is_married':False,
    'work_compant':'AW',
    'skills':['Python', 'Java', 'C++', 'ML', 'DL']
}

print(person)
# Out:
# {'first_name': 'Vikrant', 'last_name': 'Mehla', 'age': 29, 'is_married': False, 'work_compant': 'AW', 'skills': ['Python', 'Java', 'C++', 'ML', 'DL']}

# %%
print(len(person))
# Out:
# 6

# %%
print(person['first_name'])
# Out:
# Vikrant

# %%
person['can_vote'] = True

print(person)
# Out:
# {'first_name': 'Vikrant', 'last_name': 'Mehla', 'age': 29, 'is_married': False, 'work_compant': 'AW', 'skills': ['Python', 'Java', 'C++', 'ML', 'DL'], 'can_vote': True}

# %%
person['age'] = 28
print(person)
# Out:
# {'first_name': 'Vikrant', 'last_name': 'Mehla', 'age': 28, 'is_married': False, 'work_compant': 'AW', 'skills': ['Python', 'Java', 'C++', 'ML', 'DL'], 'can_vote': True}

# %%
print(person.items())
# Out:
# dict_items([('first_name', 'Vikrant'), ('last_name', 'Mehla'), ('age', 28), ('is_married', False), ('work_compant', 'AW'), ('skills', ['Python', 'Java', 'C++', 'ML', 'DL']), ('can_vote', True)])

# %%
print(person.keys())
# Out:
# dict_keys(['first_name', 'last_name', 'age', 'is_married', 'work_compant', 'skills', 'can_vote'])

# %%
print(person.values())
# Out:
# dict_values(['Vikrant', 'Mehla', 28, False, 'AW', ['Python', 'Java', 'C++', 'ML', 'DL'], True])

# %%
print(person['skills'][1])
# Out:
# Java

# %%
#looping on dictionaries

for i in person.keys():
    print(i)
# Out:
# first_name
# last_name
# age
# is_married
# work_compant
# skills
# can_vote

# %%
for i in person.values():
    print(i)
# Out:
# Vikrant
# Mehla
# 28
# False
# AW
# ['Python', 'Java', 'C++', 'ML', 'DL']
# True

# %%
for k,v in person.items():
    print(k,v)
# Out:
# first_name Vikrant
# last_name Mehla
# age 28
# is_married False
# work_compant AW
# skills ['Python', 'Java', 'C++', 'ML', 'DL']
# can_vote True

# %%
for k,v in person.items():
    print(k)
# Out:
# first_name
# last_name
# age
# is_married
# work_compant
# skills
# can_vote

# %%
for k,v in person.items():
    print(v)
# Out:
# Vikrant
# Mehla
# 28
# False
# AW
# ['Python', 'Java', 'C++', 'ML', 'DL']
# True
