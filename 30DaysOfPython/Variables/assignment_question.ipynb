# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello_World")
# Out:
# Hello_World

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
name = input("Enter Name: ")

Age = int(input("Enter age: "))

print(f'Name is {name} and Age is {Age}')
# Out:
# Name is Vikrant and Age is 29

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here

number = int(input("Enter a number"))

if(number==0):
    print("Number is 0")
elif(number>0):
    print("Number is positive")
else:
    print("Number is negative")

print(number)
# Out:
# Number is positive
# 12

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
n1 = int(input("Enter number 1"))
n2 = int(input("Enter number 2"))
n3 = int(input("Enter numner 3"))

if(n1>n2 and n1>n3):
    print(f'Greater number is {n1}')
elif(n2>n1 and n2>n3):
    print(f'Greater number if {n2}')
else:
    print(f'Greater number is {n3}')


print(n1)
print(n2)
print(n3)
# Out:
# Greater number is 34
# 12
# 23
# 34

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here

number = int(input("Enter a number: "))

y=1

while(number>0):
    y = y*number
    number-=1

print(y)
# Out:
# 120

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
var1 = 1
var2 = 1.5
var3 = "Anshul"
var4 = True

print(f'Variable 1 is {var1} and its type is {type(var1)}')
print(f'Variable 2 is {var2} and its type is {type(var2)}')
print(f'Variable 3 is {var3} and its type is {type(var3)}')
print(f'Variable 4 is {var4} and its type is {type(var4)}')
# Out:
# Variable 1 is 1 and its type is <class 'int'>
# Variable 2 is 1.5 and its type is <class 'float'>
# Variable 3 is Anshul and its type is <class 'str'>
# Variable 4 is True and its type is <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here
a= 2
b= 3

a,b = b,a

print(a)
print(b)
# Out:
# 3
# 2

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
temp  = int(input("Enter temperature"))

temp_F = 9/5*(temp) + 32

print(temp_F)
# Out:
# 89.6

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here

str1 = "Vikrant"
str2 = "Anshul"

print(str1+str2)
# Out:
# VikrantAnshul

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
var1 = int(input("Enter a number"))

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here

var1= 2
var2= 3

print(var1*var2)
print(var1+var2)
print(var2-var1)
print(var2/var1)
# Out:
# 6
# 5
# 1
# 1.5

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

n1= 10
n2= 20

print(n1==n2)
print(n1!=n2)
print(n1>n2)
print(n1<n2)
# Out:
# False
# True
# False
# True

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
n1= 10
n2= 20
n3= 30

if(n1+n2>=n3):
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here
number = 10

print(number**2)
# Out:
# 100

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here

number = int(input("Enter a number"))

if(number%2==0):
    print("Number is even")
else:
    print("Number is odd")

print(number)
# Out:
# Number is even
# 32

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

number = 20

print(number*(number+1)/2)
# Out:
# 210.0

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here
year = int(input("Enter a year"))

if(year%4==0):
    print("Leap year")
else:
    print("Npt a leap year")

print(year)
# Out:
# Leap year
# 1996

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here

name = input("Enter a name")

lst = []
for i in range(0, len(name), 1):
    lst.append(name[i])

print(lst)

newlst = lst[::-1]

x = ""

for i in range(0, len(newlst), 1):
    x=x+newlst[i]
print(x)
# Out:
# ['V', 'i', 'k', 'r', 'a', 'n', 't']
# tnarkiV

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here

var1 = input("Enter a string")

lst = []
for i in range(0, len(var1),1):
    lst.append(var1[i])

print(lst)
newlst = lst[::-1]
print(newlst)

var2 = ""

for i in range(0, len(newlst), 1):
    var2=var2+newlst[i]

if(var2==var1):
    print("String is Palindrome")
else:
    print("String is not palindrome")
# Out:
# ['h', 'a', 'n', 'n', 'a', 'h']
# ['h', 'a', 'n', 'n', 'a', 'h']
# String is Palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here
numbers = [int(x) for x in input("Enter numbers separated by space: ").split()]
numbers.sort()
print(f"Sorted list: {numbers}")
# Out:
# None
